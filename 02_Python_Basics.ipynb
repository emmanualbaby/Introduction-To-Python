# %%
X=5

# %%
Y=5

# %%
Z=5

# %%
X+Y-Z
# Out:
# 5

# %%
3+7
# Out:
# 10

# %%
7-9
# Out:
# -2

# %%
3*8
# Out:
# 24

# %%
7/7
# Out:
# 1.0

# %%
x=3
y=7
z=4
x*y*z
# Out:
# 84

# %%
x-y
# Out:
# -4

# %%
X/z
# Out:
# 1.25

# %%
x+y
# Out:
# 10

# %%
x-y-z
# Out:
# -8

# %%
X="emmanual"

# %%
Y="ikku"

# %%
X
# Out:
# 'emmanual'

# %%
Y
# Out:
# 'ikku'
