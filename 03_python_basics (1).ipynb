# %%
X=7

# %%
Y=7

# %%
Z=7

# %%
X+Y-Z
# Out:
# 7

# %%
Print="emmanual"

# %%
Print
# Out:
# 'emmanual'

# %%
X-X-X
# Out:
# -7

# %%
X*X
# Out:
# 49

# %%
Y*Y
# Out:
# 49

# %%
Name=("enter your name")

# %%
Name
# Out:
# 'enter your name'

# %%
Z=20

# %%
A=30

# %%
Name=Z-A

# %%
Name
# Out:
# -10

# %%
X-Y-Z
# Out:
# -20

# %%
"(emmanual)"
# Out:
# '(emmanual)'

# %%
1+7
# Out:
# 8

# %%
7*5
# Out:
# 35
